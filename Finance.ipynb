# %% [markdown]
# <a href="https://colab.research.google.com/github/IS737StockPicker/stonks/blob/main/Finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# I DID IT!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from plotnine import *


# IMPORT THE LIBRARY
from datetime import datetime

# CREATE TICKER INSTANCE FOR AMAZON
end_date = datetime.now().strftime('%Y-%m-%d')
stocks = ["AMZN","GOOG","MSFT","GME","TSLA"]
end_date = datetime.now().strftime('%Y-%m-%d')
i=0
test = pd.DataFrame()
for stock in stocks:
  

  stocks[i] = yf.Ticker(stock)
  stocks[i]= stocks[i].history(start='2023-01-01',end=end_date)
  ticker = stock
  #print(stocks[i])
  stocks[i]['Ticker'] = ticker
  #print(stocks[i])
  #print(stocks[0])
  test = test.append(stocks[i])
  i+=1
test['win_loss_value'] = test.Close - test.Open
test['win_loss'] = np.where(test['win_loss_value']>0, 'Up', 'Down')
test = test[['Ticker','Open','Close','win_loss_value','win_loss']]
test.reset_index(inplace=True)
test.info()
# Out:
# <ipython-input-23-200f74e2d77f>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ipython-input-23-200f74e2d77f>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ipython-input-23-200f74e2d77f>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ipython-input-23-200f74e2d77f>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            275 non-null    datetime64[ns, America/New_York]
# ...

# %%
a=test.where(test['Ticker']=='AMZN').plot('Date','Open')
b=test.where(test['Ticker']=='GOOG').plot('Date','Open')
